# %% [markdown]
# <a href="https://colab.research.google.com/github/michal670/Hron---repozit-/blob/main/Turtle_funkce_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ColabTurtle.Turtle import *

initializeTurtle()
speed(13)

colors = ["green", "limegreen", "lime", "greenyellow", "chartreuse", "yellow", "gold"]





# Spirálová hvězda
for i in range(520):
    color(colors[i % len(colors)])
    forward(i * 0.5)
    left(59)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
# !pip install ColabTurtle
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7643 sha256=29b73f35cd83cd928a252574e4b6ea16557292b198cadd1991342f2326cbaa90
#   Stored in directory: /root/.cache/pip/wheels/9f/af/64/ffd85f9858ed7d56b7293dcedbc9d461bf13c8cfc97e352bc8
# Successfully built ColabTurtle
# ...
